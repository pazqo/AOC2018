# %% [markdown]
# # Day 22
#
# [Day 22 description](https://adventofcode.com/2018/day/22)
#
# The most tricky part of this challenge was to search a path in a multi-state labyrinth. I found a solution which was not optimal, but fast enough to finish in minutes.
#
# The main idea is to create a cave large enough to contain the whole explorative area. Then, a modified Dijkstra will keep track of both the position and the tool. If I reach a previous point, with the same tool but in less time, I start exploring again. Some time could be saved by memoizing all possible paths, but this kind of optimization was not necessary.
#
# I don't have a perfect solution, meaning that I don't have a stopping condition. I just run the algorithm for enough time that no further optimizations are found for a long time (1200 steps are just enough!)

# %%
import numpy as np

# %%
with open('AOC2018_22_input.txt') as f:
    raws = [x.strip() for x in f.readlines()]

# %%
def to_int(xs): return [int(x) for x in xs]

# %%
def display_cave(cave):
    char_map = {0: '.', 1: '=', 2: '|'}
    res = ""
    x, y = cave.shape
    for i in range(y):
        row = "".join(char_map[x] for x in cave.T[i])
        res += row + "\n"
    return res

# %%
depth, (tx, ty) = int(raws[0][7:]), to_int(raws[1][8:].split(","))
#depth, (tx, ty) = 510, (10, 10)
w = tx + 200
h = ty + 200
gi_x = 16807
gi_y = 48271
el_m = 20183

# %%
def compute_gi(x, y, gi_cave):
    if x == 0 and y == 0:
        gi = 0
    elif x == tx and y == ty:
        gi = 0
    elif y == 0:
        gi = x * gi_x
    elif x == 0:
        gi = y * gi_y
    else:
        gi = el(gi_cave[x-1, y])*el(gi_cave[x, y-1]) % el_m
    return gi

# %%
def el(gi):
    return (gi + depth) % el_m

# %%
gi_cave = np.zeros((w, h), dtype=int)
for x in range(w):
    for y in range(h):
        gi_cave[x,y] = compute_gi(x, y, gi_cave)
cave = el(gi_cave) % 3
cave[:tx+1,:ty+1].sum()
# Out:
# 11575

# %%
tools = {
    0: {'climb', 'torch'},
    1: {'climb','neither'},
    2: {'torch','neither'}
}

def move_cost(source, target, old_tool):
    sp0, sp1 = source
    tp0, tp1 = target
    source_tile = cave[sp0, sp1]
    target_tile = cave[tp0, tp1]
    common_tools = tools[source_tile].intersection(tools[target_tile])
    if old_tool in common_tools:
        return (1, old_tool)
    else:
        new_tool = next(t for t in common_tools)
        return (8, new_tool)

def move(p, d):
    m = {'U': [0,-1], 'L': [-1,0], 'D': [0,1], 'R': [1,0]}
    px, py = p
    dx, dy = m[d]
    return (px + dx, py + dy)

def next_steps(p, t):
    steps = []
    if p[0] > 0:
        steps.append('L')
    if p[1] > 0:
        steps.append('U')
    if p[0] < w - 1:
        steps.append('R')
    if p[1] < h - 1:
        steps.append('D')
    return [(move(p, d), t) for d in steps]

# %%
exploration = {
    ((0,0), 'torch'): 0
}
new_points = dict()
for new_p, prev_tool in next_steps((0,0), 'torch'):
    new_time, new_tool = move_cost((0,0), new_p, prev_tool)
    new_points[(new_p, new_tool)] = new_time
exploration.update(new_points)
prev_points = dict(new_points)

# %%
i = 0
while True:
    i += 1
    if i > 1200:
        break
    new_points = dict()
    for (old_p, old_tool), old_time in prev_points.items():
        for new_p, prev_tool in next_steps(old_p, old_tool):
            if new_p == (tx, ty):
                pass
                #print("target reached!")
            new_time, new_tool = move_cost(old_p, new_p, prev_tool)
            if (new_p, new_tool) in exploration:
                prev_time = exploration[(new_p, new_tool)]
                if prev_time <= old_time + new_time:
                    pass
                else:
                    if new_p == (tx, ty):
                        print("target optimized at %s steps!" % i)
                        print(new_p, new_tool, old_time + new_time)
                    new_points[(new_p, new_tool)] = old_time + new_time
                    exploration[(new_p, new_tool)] = old_time + new_time
            else:
                new_points[(new_p, new_tool)] = old_time + new_time
                exploration[(new_p, new_tool)] = old_time + new_time
    exploration.update(new_points)
    prev_points = dict(new_points)
# Out:
# target optimized at 793 steps!
# (14, 778) climb 2103
# target optimized at 795 steps!
# (14, 778) torch 2105
# target optimized at 795 steps!
# (14, 778) climb 2049
# target optimized at 797 steps!
# (14, 778) torch 2030
# target optimized at 797 steps!
# (14, 778) climb 1988
# target optimized at 799 steps!
# (14, 778) torch 1990
# target optimized at 799 steps!
# (14, 778) climb 1948
# target optimized at 801 steps!
# (14, 778) torch 1943
# target optimized at 801 steps!
# (14, 778) climb 1901
# target optimized at 803 steps!
# (14, 778) torch 1903
# target optimized at 803 steps!
# (14, 778) climb 1861
# target optimized at 805 steps!
# (14, 778) climb 1821
# target optimized at 805 steps!
# (14, 778) torch 1863
# target optimized at 807 steps!
# (14, 778) torch 1823
# target optimized at 807 steps!
# (14, 778) climb 1781
# target optimized at 809 steps!
# (14, 778) climb 1748
# target optimized at 809 steps!
# (14, 778) torch 1783
# target optimized at 811 steps!
# (14, 778) torch 1750
# target optimized at 811 steps!
# (14, 778) climb 1715
# target optimized at 813 steps!
# (14, 778) torch 1717
# target optimized at 813 steps!
# (14, 778) climb 1689
# target optimized at 815 steps!
# (14, 778) torch 1691
# target optimized at 815 steps!
# (14, 778) climb 1663
# target optimized at 817 steps!
# (14, 778) torch 1665
# target optimized at 817 steps!
# (14, 778) climb 1644
# target optimized at 819 steps!
# (14, 778) torch 1646
# target optimized at 819 steps!
# (14, 778) climb 1625
# target optimized at 821 steps!
# (14, 778) torch 1627
# target optimized at 821 steps!
# (14, 778) climb 1606
# target optimized at 823 steps!
# (14, 778) torch 1608
# target optimized at 823 steps!
# (14, 778) climb 1587
# target optimized at 825 steps!
# (14, 778) torch 1589
# target optimized at 825 steps!
# (14, 778) climb 1568
# target optimized at 827 steps!
# (14, 778) torch 1570
# target optimized at 827 steps!
# (14, 778) climb 1549
# target optimized at 829 steps!
# (14, 778) torch 1551
# target optimized at 829 steps!
# (14, 778) climb 1530
# target optimized at 831 steps!
# (14, 778) torch 1532
# target optimized at 831 steps!
# (14, 778) climb 1518
# target optimized at 833 steps!
# (14, 778) torch 1520
# target optimized at 833 steps!
# (14, 778) climb 1499
# target optimized at 835 steps!
# (14, 778) torch 1501
# target optimized at 835 steps!
# (14, 778) climb 1487
# target optimized at 837 steps!
# (14, 778) torch 1489
# target optimized at 837 steps!
# (14, 778) climb 1475
# target optimized at 839 steps!
# (14, 778) torch 1477
# target optimized at 839 steps!
# (14, 778) climb 1463
# target optimized at 841 steps!
# (14, 778) torch 1465
# target optimized at 841 steps!
# (14, 778) climb 1451
# target optimized at 843 steps!
# (14, 778) torch 1453
# target optimized at 843 steps!
# (14, 778) climb 1439
# target optimized at 845 steps!
# (14, 778) torch 1441
# target optimized at 845 steps!
# (14, 778) climb 1427
# target optimized at 847 steps!
# (14, 778) torch 1429
# target optimized at 847 steps!
# (14, 778) climb 1415
# target optimized at 849 steps!
# (14, 778) torch 1417
# target optimized at 849 steps!
# (14, 778) climb 1396
# target optimized at 851 steps!
# (14, 778) torch 1398
# target optimized at 851 steps!
# (14, 778) climb 1384
# target optimized at 853 steps!
# (14, 778) climb 1372
# target optimized at 853 steps!
# (14, 778) torch 1386
# target optimized at 855 steps!
# (14, 778) torch 1374
# target optimized at 855 steps!
# (14, 778) climb 1360
# target optimized at 857 steps!
# (14, 778) climb 1348
# target optimized at 857 steps!
# (14, 778) torch 1362
# target optimized at 859 steps!
# (14, 778) climb 1336
# target optimized at 859 steps!
# (14, 778) torch 1350
# target optimized at 861 steps!
# (14, 778) climb 1324
# target optimized at 861 steps!
# (14, 778) torch 1338
# target optimized at 863 steps!
# (14, 778) climb 1312
# target optimized at 863 steps!
# (14, 778) torch 1326
# target optimized at 865 steps!
# (14, 778) climb 1307
# target optimized at 865 steps!
# (14, 778) torch 1314
# target optimized at 867 steps!
# (14, 778) climb 1295
# target optimized at 867 steps!
# (14, 778) torch 1309
# target optimized at 869 steps!
# (14, 778) climb 1290
# target optimized at 869 steps!
# (14, 778) torch 1297
# target optimized at 871 steps!
# (14, 778) climb 1278
# target optimized at 871 steps!
# (14, 778) torch 1292
# target optimized at 873 steps!
# (14, 778) climb 1273
# target optimized at 873 steps!
# (14, 778) torch 1280
# target optimized at 875 steps!
# (14, 778) torch 1275
# target optimized at 875 steps!
# (14, 778) climb 1268
# target optimized at 877 steps!
# (14, 778) climb 1263
# target optimized at 877 steps!
# (14, 778) torch 1270
# target optimized at 879 steps!
# (14, 778) torch 1265
# target optimized at 879 steps!
# (14, 778) climb 1251
# target optimized at 881 steps!
# (14, 778) climb 1246
# target optimized at 881 steps!
# (14, 778) torch 1253
# target optimized at 883 steps!
# (14, 778) torch 1248
# target optimized at 883 steps!
# (14, 778) climb 1234
# target optimized at 885 steps!
# (14, 778) climb 1229
# target optimized at 885 steps!
# (14, 778) torch 1236
# target optimized at 887 steps!
# (14, 778) torch 1231
# target optimized at 887 steps!
# (14, 778) climb 1224
# target optimized at 889 steps!
# (14, 778) climb 1219
# target optimized at 889 steps!
# (14, 778) torch 1226
# target optimized at 891 steps!
# (14, 778) torch 1221
# target optimized at 891 steps!
# (14, 778) climb 1207
# target optimized at 893 steps!
# (14, 778) torch 1209
# target optimized at 893 steps!
# (14, 778) climb 1202
# target optimized at 895 steps!
# (14, 778) torch 1204
# target optimized at 895 steps!
# (14, 778) climb 1197
# target optimized at 897 steps!
# (14, 778) torch 1199
# target optimized at 897 steps!
# (14, 778) climb 1192
# target optimized at 899 steps!
# (14, 778) climb 1187
# target optimized at 899 steps!
# (14, 778) torch 1194
# target optimized at 901 steps!
# (14, 778) torch 1189
# target optimized at 901 steps!
# (14, 778) climb 1182
# target optimized at 903 steps!
# (14, 778) torch 1184
# target optimized at 903 steps!
# (14, 778) climb 1177
# target optimized at 905 steps!
# (14, 778) torch 1179
# target optimized at 905 steps!
# (14, 778) climb 1172
# target optimized at 907 steps!
# (14, 778) torch 1174
# target optimized at 907 steps!
# (14, 778) climb 1167
# target optimized at 909 steps!
# (14, 778) torch 1169
# target optimized at 909 steps!
# (14, 778) climb 1162
# target optimized at 911 steps!
# (14, 778) torch 1164
# target optimized at 911 steps!
# (14, 778) climb 1157
# target optimized at 913 steps!
# (14, 778) torch 1159
# target optimized at 913 steps!
# (14, 778) climb 1152
# target optimized at 915 steps!
# (14, 778) torch 1154
# target optimized at 915 steps!
# (14, 778) climb 1147
# target optimized at 917 steps!
# (14, 778) torch 1149
# target optimized at 917 steps!
# (14, 778) climb 1142
# target optimized at 919 steps!
# (14, 778) torch 1144
# target optimized at 919 steps!
# (14, 778) climb 1137
# target optimized at 921 steps!
# (14, 778) torch 1139
# target optimized at 923 steps!
# (14, 778) climb 1134
# target optimized at 925 steps!
# (14, 778) torch 1136
# target optimized at 925 steps!
# (14, 778) climb 1129
# target optimized at 927 steps!
# (14, 778) torch 1131
# target optimized at 927 steps!
# (14, 778) climb 1124
# target optimized at 929 steps!
# (14, 778) torch 1126
# target optimized at 929 steps!
# (14, 778) climb 1119
# target optimized at 931 steps!
# (14, 778) torch 1121
# target optimized at 933 steps!
# (14, 778) climb 1116
# target optimized at 935 steps!
# (14, 778) torch 1118
# target optimized at 935 steps!
# (14, 778) climb 1111
# target optimized at 937 steps!
# (14, 778) torch 1113
# target optimized at 937 steps!
# (14, 778) climb 1106
# target optimized at 939 steps!
# (14, 778) torch 1108
# target optimized at 941 steps!
# (14, 778) climb 1103
# target optimized at 943 steps!
# (14, 778) torch 1105
# target optimized at 943 steps!
# (14, 778) climb 1098
# target optimized at 945 steps!
# (14, 778) torch 1100
# target optimized at 947 steps!
# (14, 778) climb 1095
# target optimized at 949 steps!
# (14, 778) torch 1097
# target optimized at 951 steps!
# (14, 778) climb 1092
# target optimized at 953 steps!
# (14, 778) torch 1094
# target optimized at 957 steps!
# (14, 778) climb 1091
# target optimized at 959 steps!
# (14, 778) torch 1093
# target optimized at 961 steps!
# (14, 778) climb 1088
# target optimized at 963 steps!
# (14, 778) torch 1090
# target optimized at 967 steps!
# (14, 778) climb 1087
# target optimized at 969 steps!
# (14, 778) torch 1089
# target optimized at 973 steps!
# (14, 778) climb 1086
# target optimized at 975 steps!
# (14, 778) torch 1088
# target optimized at 977 steps!
# (14, 778) climb 1083
# target optimized at 979 steps!
# (14, 778) torch 1085
# target optimized at 981 steps!
# (14, 778) climb 1080
# target optimized at 983 steps!
# (14, 778) torch 1082
# target optimized at 987 steps!
# (14, 778) climb 1079
# target optimized at 989 steps!
# (14, 778) torch 1081
# target optimized at 991 steps!
# (14, 778) climb 1076
# target optimized at 993 steps!
# (14, 778) torch 1078
# target optimized at 1003 steps!
# (14, 778) climb 1074
# target optimized at 1005 steps!
# (14, 778) torch 1076
# target optimized at 1009 steps!
# (14, 778) climb 1073
# target optimized at 1011 steps!
# (14, 778) torch 1075
# target optimized at 1013 steps!
# (14, 778) climb 1070
# target optimized at 1015 steps!
# (14, 778) torch 1072
# target optimized at 1019 steps!
# (14, 778) climb 1069
# target optimized at 1021 steps!
# (14, 778) torch 1071
# target optimized at 1023 steps!
# (14, 778) climb 1066
# target optimized at 1025 steps!
# (14, 778) torch 1068

# %%
enpoints = [(p, tool, t) for (p, tool), t in exploration.items() if p == (tx, ty)]

# %%
endtime_with_torch = [t for (p, tool), t in exploration.items() if p == (tx, ty) and tool == 'torch'][0]
endtime_with_no_torch = min([t for (p, tool), t in exploration.items() if p == (tx, ty) and tool != 'torch']) + 7
min(endtime_with_torch, endtime_with_no_torch)
# Out:
# 1068
